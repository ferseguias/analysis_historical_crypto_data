# %%
import pandas as pd
import datetime as date
import numpy as np

# %%
df = pd.read_csv("/Users/fernandoseguias/Desktop/ferseg/Proyectos/Programacion/iron_hack/project_1/output/cryptos_merged.csv")
df
# Out:
#              date  open  high  low  close  volume currency coin    price  \
# 0      18/07/2010   0.0   0.1  0.1    0.1    75.0      USD  btc      NaN
# 1      19/07/2010   0.1   0.1  0.1    0.1   574.0      USD  btc      NaN
# 2      20/07/2010   0.1   0.1  0.1    0.1   262.0      USD  btc      NaN
# 3      21/07/2010   0.1   0.1  0.1    0.1   575.0      USD  btc      NaN
# 4      22/07/2010   0.1   0.1  0.1    0.1  2160.0      USD  btc      NaN
# ...           ...   ...   ...  ...    ...     ...      ...  ...      ...
# 26363  20/11/2020   NaN   NaN  NaN    NaN     NaN      NaN  ust  0.99419
# 26364  21/11/2020   NaN   NaN  NaN    NaN     NaN      NaN  ust  1.00106
# 26365  22/11/2020   NaN   NaN  NaN    NaN     NaN      NaN  ust  0.99957
# 26366  23/11/2020   NaN   NaN  NaN    NaN     NaN      NaN  ust  1.02294
# 26367  24/11/2020   NaN   NaN  NaN    NaN     NaN      NaN  ust  0.99942
#
#        market_cap  total_volume
# 0             NaN           NaN
# ...

# %%
df_new = df[df["open"].isnull()]
df_new
# Out:
#              date  open  high  low  close  volume currency  coin    price  \
# 25481  22/09/2020   NaN   NaN  NaN    NaN     NaN      NaN  avax  5.28424
# 25482  23/09/2020   NaN   NaN  NaN    NaN     NaN      NaN  avax  5.28424
# 25483  24/09/2020   NaN   NaN  NaN    NaN     NaN      NaN  avax  3.49123
# 25484  25/09/2020   NaN   NaN  NaN    NaN     NaN      NaN  avax  4.57389
# 25485  26/09/2020   NaN   NaN  NaN    NaN     NaN      NaN  avax  4.70297
# ...           ...   ...   ...  ...    ...     ...      ...   ...      ...
# 26363  20/11/2020   NaN   NaN  NaN    NaN     NaN      NaN   ust  0.99419
# 26364  21/11/2020   NaN   NaN  NaN    NaN     NaN      NaN   ust  1.00106
# 26365  22/11/2020   NaN   NaN  NaN    NaN     NaN      NaN   ust  0.99957
# 26366  23/11/2020   NaN   NaN  NaN    NaN     NaN      NaN   ust  1.02294
# 26367  24/11/2020   NaN   NaN  NaN    NaN     NaN      NaN   ust  0.99942
#
#         market_cap  total_volume
# 25481  124357932.0   245857265.0
# ...

# %%
df_new.loc[df_new["market_cap"] == 0,["open", "high", "low", "close"]] = df_new["price"]
df_new
# Out:
# /Users/fernandoseguias/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1835: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value[:, i].tolist(), pi)
#              date     open     high      low    close  volume currency  coin  \
# 25481  22/09/2020      NaN      NaN      NaN      NaN     NaN      NaN  avax
# 25482  23/09/2020      NaN      NaN      NaN      NaN     NaN      NaN  avax
# 25483  24/09/2020      NaN      NaN      NaN      NaN     NaN      NaN  avax
# 25484  25/09/2020      NaN      NaN      NaN      NaN     NaN      NaN  avax
# 25485  26/09/2020      NaN      NaN      NaN      NaN     NaN      NaN  avax
# ...

# %%
for index, column in df_new.iterrows():
    print(column, "\n")
    print(index)
    break

# %%
df.loc[df["open"] == np.nan | df["market_cap"] == 0, ["open", "high", "low", "close"]] = df["price"]
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/roperator.py in ror_(left, right)
#      55 def ror_(left, right):
# ---> 56     return operator.or_(right, left)
#      57
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
# ...
